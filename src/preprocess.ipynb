# %%
import pymysql
host="ee542.csxuuwqqez3y.us-east-1.rds.amazonaws.com"
port=3306
dbname="gdc"
user="root"
password="uscee542wy"

from sqlalchemy import create_engine
engine = create_engine('mysql+mysqldb://root:uscee542wy@ee542.csxuuwqqez3y.us-east-1.rds.amazonaws.com/gdc')

conn = pymysql.connect(host, user=user,port=port,passwd=password, db=dbname)

# %%
import os
import numpy as np
import pandas as pd
import gzip


def read_DNA(dirname):
    count = 0
    nDNA=0
    DNA_data=[]
    #read DNA data
    for idname in os.listdir(dirname):
        # list all the ids 
        if(count > 100000):
            break
        if idname.find("-") != -1:
            idpath = dirname +"/" + idname

            # all the files in each id directory
            for filename in os.listdir(idpath):
                # check the gene file
                if filename.find("htseq.counts") != -1:

                    filepath = idpath + "/" + filename

                    df = pd.read_csv(filepath,sep="\t", header=None, index_col=0, dtype={0: str, 1:np.int32})
                    if nDNA != 0 and nDNA != len(df.index) :
                        print (filename + ", "+ idname +" mismatch")
                        print (nDNA, len(df.index))
                        continue
                    nDNA = len(df.index)
                    
                    #df = df.iloc[0:1000,:]
                    df = df.T
                    
                    df['file_id'] = idname
                    df=df.set_index('file_id')
                    if count == 0:
                        df2=df
                    else:
                        df2=df2.append(df)
                    count +=1

    print('total:',count)
    return df2

dirname='../data/gene'
df2=read_DNA(dirname)
df2.to_csv('../data/GeneExpression.csv')
df2.head(10)
# Out:
# total: 1223
# 0                                     ENSG00000000003.13  ENSG00000000005.5  \
# file_id
# 9f4ce04b-ae0f-42c1-8162-71852fd5a7c4                2292                 12
# 8525c65e-bf81-46b3-b74e-ae8260336dc4                4088                 25
# 9bc800dc-4549-47e6-817b-3097cefcd355                2781                  9
# 201d0cc6-b7e0-4770-9c60-07d5d24d9fb3                2853                  0
# dde51f9e-7dd0-42d1-9433-5f24708d0229                2090                 21
# 53c31a8a-e207-41d8-9845-3e0d0a645ee8                2604                 38
# 75882f09-d3a8-47a9-b28e-1756ac6acb29                5943                 19
# decf9f1d-5c80-444f-9764-da157150d592                3969                 18
# 6d744340-4048-4c95-ae9e-2cc02b20d5e4                8452                  0
# 83edb9b8-e212-467c-be4a-714bcec948fb                1235                  8
#
# 0                                     ENSG00000000419.11  ENSG00000000457.12  \
# file_id
# ...

# %%
df2.info()
#df2.to_sql('Gene', con=engine, if_exists='replace')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1223 entries, 9f4ce04b-ae0f-42c1-8162-71852fd5a7c4 to e47d6a84-b94d-4bce-b71c-a8f2919eb628
# Columns: 60488 entries, ENSG00000000003.13 to __alignment_not_unique
# dtypes: int32(60488)
# memory usage: 282.2+ MB

# %%
df=pd.read_csv('../data/cases_meta.tsv',sep='\t',low_memory=False)
df.to_sql('CaseMeta_Gene', con=engine, if_exists='replace')
df.head()
# Out:
#                            sample_ids.1  submitter_id  \
# 0  373dc377-6fff-473d-9884-5119ac340bee  TCGA-E2-A14V
# 1  de732898-3007-4966-be01-e601280a66dc  TCGA-E9-A1R3
# 2  bfa9b482-d082-4316-90d2-8b9c4a993744  TCGA-A2-A0T4
# 3  42cd6126-fbfc-4181-80da-66ece205fad7  TCGA-AC-A7VC
# 4  c0495a7e-f518-469d-b716-3b431581fd7f  TCGA-A7-A13E
#
#        submitter_aliquot_ids.28  exposures.0.bmi  \
# 0                           NaN              NaN
# 1                           NaN              NaN
# 2                           NaN              NaN
# 3                           NaN              NaN
# 4  TCGA-A7-A13E-10A-02D-A272-09              NaN
#
#        submitter_aliquot_ids.24      submitter_aliquot_ids.25  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# ...

# %%
df=pd.read_csv('../data/files_meta.tsv',sep='\t',low_memory=False)
df.to_sql('FileMeta_Gene', con=engine, if_exists='replace')
df.head()
# Out:
#   cases.0.samples.0.portions.0.analytes.0.aliquots.0.aliquot_id  \
# 0               34dfa8c6-6445-4ef8-bc3b-b2ba600b5808
# 1               67a58c72-fa64-4c63-b568-bec834626edf
# 2               3e775d6c-3845-49a7-80e0-82c5c68a473c
# 3               95817802-63d7-4dd4-902f-3c61332e017c
# 4               e5949631-ebaf-4ec2-aac8-b0a6fd51d946
#
#                         data_type cases.0.samples.0.sample_type  \
# 0  Gene Expression Quantification                 Primary Tumor
# 1  Gene Expression Quantification                 Primary Tumor
# 2  Gene Expression Quantification                 Primary Tumor
# 3  Gene Expression Quantification                 Primary Tumor
# 4  Gene Expression Quantification                 Primary Tumor
#
#                                            file_name  \
# 0  36725a42-52bc-4e9a-bb7c-728fbb8b1d19.FPKM-UQ.t...
# 1  6f618400-b914-4103-bf46-9c026b470aa0.FPKM-UQ.t...
# 2  e023c283-afcf-4334-b741-3dce8e98b0f6.htseq.cou...
# ...

# %%
import boto3
s3 = boto3.client('s3')

s3.upload_file('../data/GeneExpression.csv', 'ee542wy', 'GeneExpression.csv')

s3.upload_file('../data/miRNA_matrix.csv', 'ee542wy', 'miRNA_matrix.csv')
s3.upload_file('../data/primary_site_code.csv', 'ee542wy', 'primary_site_code.csv')

s3.upload_file('../data/files_meta.tsv', 'ee542wy', 'files_meta.tsv')
s3.upload_file('../data/cases_meta.tsv', 'ee542wy', 'cases_meta.tsv')
